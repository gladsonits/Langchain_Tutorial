# %% [markdown]
# **LLM CALL**

# %%
from langchain_ollama import ChatOllama

model = ChatOllama(
    model="llama3.1",
    validate_model_on_init=True,
    temperature=0.8,
    num_predict=256,
    # other params ...
)

messages = [
    ("system", "You are a helpful translator. Translate the user sentence to French."),
    ("human", "I love programming."),
]
model.invoke(messages).content
# Out:
# 'Translation: "J\'adore la programmation."'

# %%
from langchain.chat_models import init_chat_model

chat_model=init_chat_model(
    model="llama3.1",
    temperature=0.8,
    num_predict=256,
    model_provider="ollama",
    validate_model_on_init=True,)

chat_model.invoke("Hello!. I am Rose. How are you?").content
# Out:
# "Hello Rose! I'm just a computer program, so I don't have feelings or emotions like humans do, but I'm functioning properly and ready to chat with you! It's great to meet you. How about you? How's your day going so far?"
