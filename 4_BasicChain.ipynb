# %% [markdown]
# **CHAINS**

# %%
from langchain_core.messages import SystemMessage, HumanMessage, AIMessage
from langchain_ollama import ChatOllama
from langchain_core.output_parsers import StrOutputParser
from langchain_core.prompts import ChatPromptTemplate, MessagesPlaceholder

# %%
#Prompt template for the chain

prompt_template = ChatPromptTemplate.from_template(
    "You are a helpful assistant that translates {input_language} to {output_language}."
)

input_language = "English"
output_language = "French"

ready_input = prompt_template.format_messages(input_language=input_language, output_language=output_language)

# %%
# LLM initialization
model = ChatOllama(
    model="llama3.1",
    validate_model_on_init=True,
    temperature=0.8,
    num_predict=256,
    # other params ...
)

# %%
#String output parser initialization

output_parser = StrOutputParser()

response = model.invoke(ready_input).content

response
# Out:
# "Bonjour! I'd be delighted to assist you with translating English to French. What would you like me to translate for you? A sentence, a phrase, a paragraph, or perhaps a document?\n\nPlease keep in mind that I'll do my best to provide an accurate and natural-sounding translation, but if you need a formal or professional translation, it's always best to consult a certified translator or a professional translation service.\n\nQu'est-ce que vous voudriez que je traduise? (What would you like me to translate?)"

# %%
# CHAIN CALLING

chain = prompt_template | model | output_parser

chain.invoke({"input_language": "English", "output_language": "French"})
# Out:
# "Je suis à votre service ! (I'm at your service!)\n\nWhat would you like me to translate? A sentence, a phrase, or a whole text? Please let me know and I'll do my best to provide an accurate translation.\n\nNote: If you have a specific dialect or regional variation of French in mind (e.g. Quebecois, Swiss, Belgian, etc.), please let me know so I can provide the most relevant translation.\n\nAllons-y ! (Let's go!)"
